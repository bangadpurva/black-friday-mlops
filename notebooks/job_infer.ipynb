# %%
import os
import sys
import importlib

sys.path.append("../src")

import infer_sklearn
importlib.reload(infer_sklearn)

os.environ.setdefault("TEST_TABLE", "main.default.test")
os.environ.setdefault("PRED_TABLE", "main.default.black_friday_predictions")
os.environ.setdefault("MLFLOW_EXPERIMENT", "/Shared/black-friday-mlops")
os.environ.setdefault("MONITOR_TABLE", "main.default.black_friday_monitoring")

infer_sklearn.main()
