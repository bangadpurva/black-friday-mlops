# %%
import sys, importlib
sys.path.append("../src")

import infer_sklearn
importlib.reload(infer_sklearn)

# Optional sampling if test is huge:
import os
os.environ["SAMPLE_N"] = "200000"

infer_sklearn.main()
