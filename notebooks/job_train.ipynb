# %%
import os
import sys
import importlib

# Ensure repo src is importable
sys.path.append("../src")

import train_sklearn
importlib.reload(train_sklearn)

# Optional: set defaults for jobs (you can change later in Job parameters)
os.environ.setdefault("TRAIN_TABLE", "main.default.train")
os.environ.setdefault("MLFLOW_EXPERIMENT", "/Shared/black-friday-mlops")
os.environ.setdefault("SAMPLE_N", "200000")  # uncomment if you want sampling

train_sklearn.main()
