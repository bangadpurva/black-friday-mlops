# %%
import sys, importlib
sys.path.append("../src")

import train_sklearn
importlib.reload(train_sklearn)

# Optional: if your table is huge, set a sample first
import os
os.environ["SAMPLE_N"] = "200000"

train_sklearn.main()
